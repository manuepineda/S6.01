# %% [markdown]
# ## SPRINT 6 , NIVEL 1

# %% [markdown]
# ![image-2.png](attachment:image-2.png)
#
#
# Ejercicio 1:
#
# L'empresa necessita avaluar el rendiment de les vendes a nivell internacional. Com a part d'aquest procés, et demanen que triïs un gràfic en el qual es detalli la mitjana de vendes desglossades per país i any en una mateixa presentació visual. És necessari assenyalar les mitjanes que són menors a 200 euros anuals.
#
# ![image.png](attachment:image.png)
#
# FORMULA DAX PARA LA MEDIA:
#
# Media de ventas = AVERAGE('s401 transactions'[amount])
#
# En este gráfico podemos observar la media de ventas por pais y año (2021 & 2022). 2021 fue el año con mas ventas de media, aunque estos datos pueden confundir, ya que 2022 solo posee datos de los primeros 3 meses del año. La ventas disminuyeron en todos los paises de 2021 a 2022, con expececión de Irlanda, Italia y Nueva Zelanda, países que incrementaron sus ventas en el año 2022, con Nueva Zelanda convirtiéndose en el país con mayor media de ventas.
#
# En cuanto al kpi de 200€, españa italia y nueva zelanda estuvieron por debajo en 2021, y en 2022, Canada, Belgica, China, Australia y Francia.

# %% [markdown]
# Ejercicio 2:
#
# L'empresa està interessada a obtenir una visió general de les transaccions realitzades per cada país. La teva tasca és crear una visualització que identifiqui el percentatge de les vendes per país.
#
# ![image.png](attachment:image.png)
#
#
# La mitad de las ventas totales pertenecientes a los años 2021 y 2022 pertenecen a Alemania, Reino Unido y Suecia. Lo que tienen estos tres países en común es el hecho de que mantienen unas ventas consistentes a través del año, resaltando la importancia de establecer partnertships estables a lo largo del tiempo. Adicionalmente, son países de alto poder adquisitivo, lo cual explica parcialmente esta gran aportación a los porcentajes de ventas.

# %% [markdown]
# Ejercicio 3:
#
# Dissenya un indicador visual en Power BI per a analitzar la diferència de vendes entre els anys 2022 i 2021 en cada país. L'empresa està interessada a comprendre com han variat les vendes en diferents països durant aquest període i desitja identificar qualsevol disminució o augment significatiu en les vendes.
#
# ![image.png](attachment:image.png)
#
#
# ![image-3.png](attachment:image-3.png)
#
# En la primera gráfica podemos observar como hay un descenso de ventas de 2021 a 2022 en la mayoría de países. Esta tendencia se da debido a la falta de datos para los meses de abril a diciembre en 2022, de ahí la menor cantidad de ventas totales en 2022. Para solventar esta problemática, hemos creado una segunda gráfica seleccionando solos los primeros tres meses del año, tanto en 2021 como en 2022. La interpretación cambia significativamente. De este modo, con la segunda gráfica desvelamos como la gran mayoría de paises de hecho incrementan sus ventas en enero febrero y marzo de 2022 con respecto a 2021.

# %% [markdown]
# Ejercicio 4:
#
# Crea una visualització en la qual es pugui comptabilitzar el nombre de transaccions rebutjades en cada país per a mesurar l'eficàcia de les operacions. Recorda que l'empresa espera tenir menys de 5 transaccions rebutjades per país.
#
# ![image.png](attachment:image.png)
#
# FÓRMULA DAX PARA CONTABILIZAR DECLINED (el formato se tuvo que cambiar de texto a número entero en power query):
#
# Declinadas =
# CALCULATE(
#     COUNTROWS('s401 transactions'),
#     's401 transactions'[declined] = 1
# )
#
#
# La mayoría de empresas rebasan el kpi de 5 transacciones rechazadas maximas, con los casos de suecia. italia y países bajos a la cabeza. Es importante señalar que un mayor numero de transacciones rechazadas esta positivamente correlacionado con un mayor número de transacciones y en el caso de estos países, resultan ser países con las mayores porporciones de ventas totales de todos los países, por tanto, es natural ver una cifra de declinadas mayor. Desde el equipo de analisis acosejamos se revise el kpi y que en vez de un monto de 5, sea un valor proporcional. Por ejemplo, que solo haya un 5% max de transacciones declinadas. En cuanto a reducir transacciones declinadas en sí, hay varios factores. Uno, la cultura de consumo favorece probar los productos primero, luego quedarselos, por tanto es normal ver mayores cantidades de transacciones declinadas. Dos, los productos tienen que tener un control de calidad y satisfacción de clientes excelentes para reducir el número de devoluciones al mínimo, ya que las devoluciones también reflejan un cliente posiblemente insatisfecho.

# %% [markdown]
# Ejercicio 5:
#
# L'empresa busca comprendre la distribució geogràfica de les vendes per a identificar patrons i oportunitats específiques en cada regió. Selecciona la millor visualització per a mostrar aquesta informació.
#
# ![image.png](attachment:image.png)
#
# FORMULA DAX:
#
# Location = 's401 users'[country] & " " & 's401 users'[city] (esto me permitio crear una localización por la cual el oobjeto visual de mapa podía identificar las ciudades por país sin confundir ciudades con el mismo nombre)
#
# Esta gráfica muestra la distribución de los usuarios en canada, USA y UK. UK es de distribucion densa, con individuos en todo el territorio. USA muestra la gran mayoría de sus usuarios en las costas este y oeste. Canada muestra un patron similar a USA, añadiendo la mayor densida de usuarios en el sur del territorio debido a cuestiones de habitabilidad y densidad de población.
#
# (tenía que cambiar los datos aquí, en vez de mostrar usuarios mostra ventas por localizacion. Como no funcionan los mapas ahora, no lo puedo cambiar, por eso muestro lo que puedo. Aunque si pudiera, hubiera utilizado el campo city y hubiera mostrado las ventas totales por ciudad en cada burbuja, así mostrando las ciudades con mayor consumo.)

# %% [markdown]
# Ejercicio 6:
#
# El teu cap t'ha demanat preparar una presentació per al teu equip en la qual es detallin la informació de tots els gràfics visualitzats fins ara. Per a complir amb aquesta sol·licitud, has de proporcionar una interpretació de les visualitzacions obtingudes. La presentació pot realitzar-se amb la informació general o seleccionant un element en particular, com per exemple, els resultats d'Espanya.
#
# Los ejercicios descritos arriba son la compleción de este ejercicio 6.
